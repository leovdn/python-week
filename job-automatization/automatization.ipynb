# %% [markdown]
# ## Job Automatization
#
# #### Requirements
# - Search stock market infos automaticaly
# - Create requested analysis
#   - Max quotation
#   - Min quotation
#   - Average price
#
# - Send the Manager automatic e-mails

# %% [markdown]
# ### 1. Search stock market infos automaticaly
#
# Libraries: `yfanance` & `matplotlib`

# %%
import yfinance
import matplotlib

# %%
ticker = input("Insert the stock ticker: ")
stock_data = yfinance.Ticker(ticker).history(start="2022-01-01", end="2022-12-31")

year_end_close = stock_data.Close
year_end_close.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Create Requested Analysis

# %%
max_quotation = round(year_end_close.max(), 2)
min_quotation = round(year_end_close.min(), 2)
average_quotation = round(year_end_close.mean(), 2)

print(f"Max: {max_quotation}")
print(f"Min: {min_quotation}")
print(f"Average: {average_quotation}")
# Out:
# Max: 30.08
# Min: 11.22
# Average: 18.55

# %% [markdown]
# ### 3. Send e-mails automaticaly
# - Open browser and e-mail
# - Click on Write button
# - Type the recipient's e-mail
# - Type the subject and hit TAB
# - Type the message
# - Click on SUBMIT button
#
# Libraries: `pyautogui`, `pyperclip`, `webbrowser`

# %%
import pyautogui
import pyperclip
import webbrowser
import time

recipient = "leo.vdn@gmail.com"
subject = "Python Automatization Practice"
message = f"""
Dear manager,

We have received your request to get the {ticker} stock quotation:

Max: R$ {max_quotation}
Min: R$ {min_quotation}
Average: R$ {average_quotation}

Any doubts, please contact us!

Best regards,

The Leovdn Automatization Team

"""

# Open Browser
webbrowser.open("https://mail.google.com")
time.sleep(3)

# Pausing for 3 seconds before click
pyautogui.PAUSE = 3

# Click on Write button
pyautogui.click(x=1319, y=-921)

# Type recipient's email address
pyperclip.copy(recipient)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

# Type the e-mail subject
pyperclip.copy(subject)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

# Type the e-mail message
pyperclip.copy(message)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

# Send e-mail
pyautogui.click(x=1738, y=-103)

# %%
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=1738, y=-103)
